# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Final-Project-Submission" data-toc-modified-id="Final-Project-Submission-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Final Project Submission</a></span></li><li><span><a href="#Importing-Libraries-and-Data" data-toc-modified-id="Importing-Libraries-and-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Importing Libraries and Data</a></span><ul class="toc-item"><li><span><a href="#head()" data-toc-modified-id="head()-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>head()</a></span></li><li><span><a href="#describe()" data-toc-modified-id="describe()-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>describe()</a></span></li><li><span><a href="#info()" data-toc-modified-id="info()-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>info()</a></span></li><li><span><a href="#First-Model" data-toc-modified-id="First-Model-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>First Model</a></span></li><li><span><a href="#Plot-coefficients" data-toc-modified-id="Plot-coefficients-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Plot coefficients</a></span></li><li><span><a href="#Plot-correlation" data-toc-modified-id="Plot-correlation-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Plot correlation</a></span></li></ul></li><li><span><a href="#Scrubbing-Data" data-toc-modified-id="Scrubbing-Data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Scrubbing Data</a></span><ul class="toc-item"><li><span><a href="#Regplots-of-all-columns" data-toc-modified-id="Regplots-of-all-columns-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Regplots of all columns</a></span></li><li><span><a href="#Making-categorical-columns" data-toc-modified-id="Making-categorical-columns-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Making categorical columns</a></span><ul class="toc-item"><li><span><a href="#Cleaning-sqft_basement" data-toc-modified-id="Cleaning-sqft_basement-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Cleaning sqft_basement</a></span></li><li><span><a href="#Adding-half_story-and-has_basement" data-toc-modified-id="Adding-half_story-and-has_basement-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Adding half_story and has_basement</a></span></li></ul></li><li><span><a href="#Dealing-with-null-values" data-toc-modified-id="Dealing-with-null-values-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Dealing with null values</a></span><ul class="toc-item"><li><span><a href="#Making-one-hot-encoded" data-toc-modified-id="Making-one-hot-encoded-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Making one hot encoded</a></span></li></ul></li><li><span><a href="#Finding-r_squared-for-all" data-toc-modified-id="Finding-r_squared-for-all-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Finding r_squared for all</a></span></li><li><span><a href="#Dropping-low-r_squared" data-toc-modified-id="Dropping-low-r_squared-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Dropping low r_squared</a></span></li><li><span><a href="#Variance-Inflation-Factor" data-toc-modified-id="Variance-Inflation-Factor-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Variance Inflation Factor</a></span></li></ul></li><li><span><a href="#Scrub-2" data-toc-modified-id="Scrub-2-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Scrub 2</a></span><ul class="toc-item"><li><span><a href="#Define-new-categorical-columns" data-toc-modified-id="Define-new-categorical-columns-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Define new categorical columns</a></span></li><li><span><a href="#Make-new-dataframe" data-toc-modified-id="Make-new-dataframe-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Make new dataframe</a></span></li><li><span><a href="#Making-month-column" data-toc-modified-id="Making-month-column-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Making month column</a></span></li><li><span><a href="#Fixing-floors-and-bathrooms" data-toc-modified-id="Fixing-floors-and-bathrooms-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Fixing floors and bathrooms</a></span></li><li><span><a href="#Outlier-Removal" data-toc-modified-id="Outlier-Removal-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Outlier Removal</a></span><ul class="toc-item"><li><span><a href="#Value-counts-before" data-toc-modified-id="Value-counts-before-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Value counts before</a></span></li><li><span><a href="#Removal" data-toc-modified-id="Removal-4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span>Removal</a></span></li><li><span><a href="#Value-counts-after" data-toc-modified-id="Value-counts-after-4.5.3"><span class="toc-item-num">4.5.3&nbsp;&nbsp;</span>Value counts after</a></span></li></ul></li></ul></li><li><span><a href="#Test-Modeling" data-toc-modified-id="Test-Modeling-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Test Modeling</a></span><ul class="toc-item"><li><span><a href="#Train-Test-Split-df2_ohe2" data-toc-modified-id="Train-Test-Split-df2_ohe2-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Train Test Split df2_ohe2</a></span></li><li><span><a href="#One-hot-encoding-df2" data-toc-modified-id="One-hot-encoding-df2-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>One hot encoding df2</a></span></li><li><span><a href="#Check-vif-correlation" data-toc-modified-id="Check-vif-correlation-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Check vif correlation</a></span></li></ul></li><li><span><a href="#Explore" data-toc-modified-id="Explore-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Explore</a></span><ul class="toc-item"><li><span><a href="#Outlier-Removal" data-toc-modified-id="Outlier-Removal-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Outlier Removal</a></span></li></ul></li><li><span><a href="#Goal-Model" data-toc-modified-id="Goal-Model-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Goal Model</a></span></li><li><span><a href="#Model" data-toc-modified-id="Model-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Model</a></span></li></ul></div>

# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %% [markdown]
# > This project was done with the OSEMN Process
# >- **O**btain
# - **S**crub
# - **E**xplor
# - **M**odel
# - I**N**terpret

# %% [markdown]
# ## Importing Libraries and Data

# %%
slow = True  # skips large graphs, and modelings

# %%
from mltools.mlframe import MLFrame
help(MLFrame)
# Out:
# C:\Users\12147\anaconda3\envs\learn-env\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Help on class MLFrame in module mltools.mlframe:
#
# class MLFrame(pandas.core.frame.DataFrame)
#  |  A pd.DataFrame with an inplace model, and LinearRegression
#  |  modeling functions.
#  |
#  |  **See pandas.DataFrame documentation
#  |
#  |  Method resolution order:
#  |      MLFrame
#  |      pandas.core.frame.DataFrame
#  |      pandas.core.generic.NDFrame
#  |      pandas.core.base.PandasObject
#  |      pandas.core.accessor.DirNamesMixin
#  |      pandas.core.base.SelectionMixin
#  |      pandas.core.indexing.IndexingMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getitem__(self, key)
#  |      Wrapper for get item [] so that it returns an
#  |      MLFrame rather then a pd.DataFrame
#  |
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
df = MLFrame(pd.read_csv('kc_house_data.csv'))
pd.set_option('display.max_columns',0)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
mpl.rcParams['xtick.labelsize'] = 15
mpl.rcParams['ytick.labelsize'] = 15
mpl.rcParams['axes.labelsize'] = 20

# %% [markdown]
# ### head()

# %%
df.head()
# Out:
#            id        date      price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  10/13/2014 221900.000  ... -122.257           1340        5650
# 1  6414100192   12/9/2014 538000.000  ... -122.319           1690        7639
# 2  5631500400   2/25/2015 180000.000  ... -122.233           2720        8062
# 3  2487200875   12/9/2014 604000.000  ... -122.393           1360        5000
# 4  1954400510   2/18/2015 510000.000  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ### describe()

# %%
df.describe()
# Out:
#                   id       price  bedrooms  ...      long  sqft_living15  sqft_lot15
# count      21597.000   21597.000 21597.000  ... 21597.000      21597.000   21597.000
# mean  4580474287.771  540296.574     3.373  ...  -122.214       1986.620   12758.284
# std   2876735715.748  367368.140     0.926  ...     0.141        685.230   27274.442
# min      1000102.000   78000.000     1.000  ...  -122.519        399.000     651.000
# 25%   2123049175.000  322000.000     3.000  ...  -122.328       1490.000    5100.000
# 50%   3904930410.000  450000.000     3.000  ...  -122.231       1840.000    7620.000
# 75%   7308900490.000  645000.000     4.000  ...  -122.125       2360.000   10083.000
# max   9900000190.000 7700000.000    33.000  ...  -121.315       6210.000  871200.000
#
# [8 rows x 19 columns]

# %% [markdown]
# ### info()

# %%
df.info()
# Out:
# Model is None
#
# <class 'mltools.mlframe.MLFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %% [markdown]
# ### First Model

# %%
help(df.model_and_plot)
# Out:
# Help on method model_and_plot in module mltools.mlframe:
#
# model_and_plot(target, figsize=(10, 10), **kwargs) method of mltools.mlframe.MLFrame instance
#     Creates a new model based on target, plots a
#     scatter plot of (target, model residuals), and
#     plots a qqplot based on the model residuals.
#
#     Parameters
#     ----------------------------------------
#     target::[str]
#         The target for which to model on
#     kwargs{dict}::
#         Arguments that are sent to Model.from_formula()
#         see:
#     https://www.statsmodels.org/stable/generated/statsmodels.formula.api.ols.html
#
#     Returns
#     ----------------------------------------
#     model
#
#     Example Usage
#     ----------------------------------------
#     >>> df = MLFrame(pd.read_csv('mltools/tests/auto-mpg.csv'))
#     >>> df.clean_col_names(inplace=True)
#     >>> df.model_and_plot('mpg')

# %%
help(df.fill_na_mode)
# Out:
# Help on method fill_na_mode in module mltools.mlframe:
#
# fill_na_mode(inplace=False, verbose=True) method of mltools.mlframe.MLFrame instance
#     Fills na cells with the mode of it's
#     respective column
#
#     Parameters
#     ----------------------------------------
#     inplace[bool]::
#         Defines whether to return a new dataframe or
#         mutate the dataframe.
#     verbose[bool]::
#         Whether to print out the filling information
#         or not.
#
#     Returns
#     ----------------------------------------
#     None if inplace, otherwise returns copy of dataframe
#     with nulls filled with mode
#
#     Example Usage
#     ----------------------------------------
#     >>> df = MLFrame(pd.DataFrame(np.arange(12).reshape(3, 4),
#     ...                   columns=['A', 'B', 'C', 'D']))
#     >>> df['A'].loc[1:3] = np.nan
#     >>> df['B'].loc[0] = np.nan
#     >>> df
#         A    B   C   D
#     0  0.0  NaN   2   3
#     1  NaN  5.0   6   7
# ...

# %%
# Not setting it to df, so I can clean sqft_basement later

first_model = df.fill_na_mode(verbose=False  # Fill na for the model
        ).drop(['date', 'sqft_basement'], axis=1  # Dropping date and
        ).model_and_plot('price')                 # sqft_basement for example
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     2798.
# Date:                Thu, 03 Sep 2020   Prob (F-statistic):               0.00
# Time:                        03:08:38   Log-Likelihood:            -2.9439e+05
# No. Observations:               21597   AIC:                         5.888e+05
# Df Residuals:                   21578   BIC:                         5.890e+05
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Plot coefficients

# %%
help(df.plot_coef)
# Out:
# Help on method plot_coef in module mltools.mlframe:
#
# plot_coef(cmap='Greens') method of mltools.mlframe.MLFrame instance
#     Plots a predefined plot
#     of the model's coefficients
#
#     cmap[str]:: Default is Greens
#         The style.background_gradient color
#         see:
#     https://matplotlib.org/3.3.1/tutorials/colors/colormaps.html
#
#     Returns
#     ----------------------------------------
#     <pandas.io.formats.style.Styler>
#
#     Example Usage
#     ----------------------------------------
#     >>> df = MLFrame(pd.read_csv('mltools/tests/auto-mpg.csv'))
#     >>> df.clean_col_names(inplace=True, verbose=False)
#     >>> df.drop('car_name', axis=1, inplace=True)
#     >>> df.plot_corr(annot=True)

# %%
df.model = first_model
df.plot_coef()
# Out:
# <style  type="text/css" >
# #T_ac2732f4_edbc_11ea_b00e_04d9f5827febrow0_col0{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_ac2732f4_edbc_11ea_b00e_04d9f5827febrow1_col0,#T_ac2732f4_edbc_11ea_b00e_04d9f5827febrow2_col0{
#             background-color:  #e7f6e2;
#             color:  #000000;
#         }#T_ac2732f4_edbc_11ea_b00e_04d9f5827febrow3_col0{
#             background-color:  #f1faee;
#             color:  #000000;
#         }#T_ac2732f4_edbc_11ea_b00e_04d9f5827febrow4_col0,#T_ac2732f4_edbc_11ea_b00e_04d9f5827febrow5_col0{
#             background-color:  #f2faef;
#             color:  #000000;
#         }#T_ac2732f4_edbc_11ea_b00e_04d9f5827febrow6_col0,#T_ac2732f4_edbc_11ea_b00e_04d9f5827febrow7_col0{
#             background-color:  #f2faf0;
#             color:  #000000;
# ...

# %% [markdown]
# ### Plot correlation

# %%
help(df.plot_corr)
# Out:
# Help on method plot_corr in module mltools.mlframe:
#
# plot_corr(figsize=(25, 25), annot=False, **kwargs) method of mltools.mlframe.MLFrame instance
#     Plots a predefined correlation heatmap
#
#     Parameters
#     ----------------------------------------
#     figsize(tu, ple)::
#         The size of the plotted figure
#     annot[bool]::
#         Whether or not to annotate the cells
#     kwargs{dict}::
#         Arguments that are sent to sns.heatmap
#         see:
#     https://seaborn.pydata.org/generated/seaborn.heatmap.html
#
#     Returns
#     ----------------------------------------
#     fig, ax
#
#     Example Usage
#     ----------------------------------------
#     >>> df = MLFrame(pd.read_csv('mltools/tests/auto-mpg.csv'))
#     >>> df.clean_col_names(inplace=True, verbose=False)
#     >>> df.drop('car_name', axis=1, inplace=True)
#     >>> df.plot_corr(annot=True)

# %%
df.plot_corr(annot=True)
# Out:
# (<Figure size 1800x1800 with 2 Axes>, <AxesSubplot:>)

# %% [markdown]
# ## Scrubbing Data

# %%
help(df.regplot)
# Out:
# Help on method regplot in module mltools.mlframe:
#
# regplot(x, y, **kwargs) method of mltools.mlframe.MLFrame instance
#     Plots a seaborn regplot of x and y
#
#     Parameters
#     ----------------------------------------
#     x[str]::
#         Name of a column to plot x
#     y[str]::
#         Name of a column to plot y
#     kwargs{dict}::
#         Arguments that are sent to sns.regplot
#         see:
#     https://seaborn.pydata.org/generated/seaborn.regplot.html
#
#     Returns
#     ----------------------------------------
#     an sns.regplot
#
#     Example Usage
#     ----------------------------------------
#     >>> df = MLFrame(pd.read_csv('mltools/tests/auto-mpg.csv'))
#     >>> fig, ax = plt.subplots()
#     >>> df.regplot('horsepower', 'mpg', ax=ax)

# %% [markdown]
# ### Regplots of all columns

# %%
if False:
    for col in df.num_cols():
        df.regplot(col, 'price')
        plt.show()

# %% [markdown]
# ### Making categorical columns
# > - Dropping house id, date of sale, lat, and long
# - Fixing basement

# %% [markdown]
# #### Cleaning sqft_basement

# %%
df['sqft_basement'] = df['sqft_basement'].apply(lambda x: 0 if x == '?' else x)
df['sqft_basement'] = df['sqft_basement'].astype(float)

# %% [markdown]
# #### Adding half_story and has_basement

# %%
df['half_story'] = df['floors'].apply(lambda x: 0 if x%1 == 0 else 1)
df['has_basement'] = df['sqft_basement'].apply(lambda x: 1 if x > 0 else 0)
df['half_story'].value_counts(), df['has_basement'].value_counts()
# Out:
# (0    19519
#  1     2078
#  Name: half_story, dtype: int64, 0    13280
#  1     8317
#  Name: has_basement, dtype: int64)

# %%
help(df.one_hot_encode)
# Out:
# Help on method one_hot_encode in module mltools.mlframe:
#
# one_hot_encode(columns=[], drop_first=True, verbose=True, **kwargs) method of mltools.mlframe.MLFrame instance
#     Makes a one hot encoded dataframe
#
#     Parameters
#     ----------------------------------------
#     columns[list]::
#         list of columns to one hot encode
#         uses self.cat_cols() if not defined
#     drop_first=True::
#         whether to drop the first column or not
#         to rid of multicollinearity
#     verbose[bool]::
#         Whether to print out the series or not
#     kwargs{dict}::
#         Arguments to send to pd.get_dummies
#         see:
#     https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.get_dummies.html
#
#     Returns
#     ----------------------------------------
#     encoded dataframe
#
#     Example Usage
#     ----------------------------------------
#     >>> df = MLFrame(pd.read_csv('mltools/tests/auto-mpg.csv'))
# ...

# %%
df.info()
# Out:
# Model is <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000002BE5B8C3550>
#
# <class 'mltools.mlframe.MLFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  float64
#  14  yr_built       21597 non-null  int64
# ...

# %% [markdown]
# ### Dealing with null values

# %%
df['waterfront'].fillna(0, inplace=True)
df['yr_renovated'].fillna(0, inplace=True)
df.fill_na_mode(inplace=True)
# Out:
# % of view with 0   0.000
# Name: view, dtype: float64

# %%
# removing half_stories i.e (1.5, 2.5, 3.5)
df['floors'] = df['floors'].astype('int64')

# %% [markdown]
# #### Making one hot encoded

# %%
cat_cols = ['zipcode', 'view', 'floors']
for col in cat_cols:
    df[col] = df[col].astype('category')
df_ohe = df.drop(['date', 'id', 'lat', 'long'], axis=1).one_hot_encode(cat_cols)
df_ohe = df_ohe.scale(['yr_built'])  # was an issue in VIF
# Out:
# Added categorical columns
# 2 -> sqft_living
# 2 -> sqft_lot
# 2 -> floors
# 4 -> view
# 69 -> zipcode
# Scaling:
#    yr_built

# %%
df_ohe.drop([x for x in df_ohe.columns if 'zipcode' in x], axis=1).plot_corr(annot=True)
# Out:
# (<Figure size 1800x1800 with 2 Axes>, <AxesSubplot:>)

# %%
df_ohe.head()
# Out:
#        price  bedrooms  bathrooms  ...  view_4.0  floors_2  floors_3
# 0 221900.000         3      1.000  ...         0         0         0
# 1 538000.000         3      2.250  ...         0         1         0
# 2 180000.000         2      1.000  ...         0         0         0
# 3 604000.000         4      3.000  ...         0         0         0
# 4 510000.000         3      2.000  ...         0         0         0
#
# [5 rows x 91 columns]

# %% [markdown]
# ### Finding r_squared for all

# %%
r_squared = {}
df_ohe.clean_col_names(inplace=True)
for col in df_ohe.columns:
    model = df_ohe.lrmodel('price', [col])
    r_squared[col] =  model.rsquared

sorted(r_squared.items(), key=lambda x: x[1])
# Out:
# Columns changed:
# view_1.0 --> view_1_0
# view_2.0 --> view_2_0
# view_3.0 --> view_3_0
# view_4.0 --> view_4_0
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 9.579e+31
# Date:                Thu, 03 Sep 2020   Prob (F-statistic):               0.00
# Time:                        03:08:40   Log-Likelihood:             3.8004e+05
# No. Observations:               21597   AIC:                        -7.601e+05
# Df Residuals:                   21595   BIC:                        -7.601e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ### Dropping low r_squared

# %%
cat_low = [x for x in df_ohe.columns if 'zipcode' in x]
cat_low = cat_low + [x for x in df_ohe.columns if 'floors' in x]
df_test = df_ohe.drop(cat_low, axis=1)
r_squared = {}
for col in df_test.columns:
    model = df_test.lrmodel('price', [col])
    r_squared[col] =  model.rsquared

rs = pd.Series(r_squared)
sorted_rs = rs.sort_values()
sorted_rs
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 9.579e+31
# Date:                Thu, 03 Sep 2020   Prob (F-statistic):               0.00
# Time:                        03:08:42   Log-Likelihood:             3.8004e+05
# No. Observations:               21597   AIC:                        -7.601e+05
# Df Residuals:                   21595   BIC:                        -7.601e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.829e-10   6.68e-11     -4.238      0.000   -4.14e-10   -1.52e-10
# ...

# %%
#cols = list(sorted_rs['sqft_lot': 'price'].index)
df_new = df_test.copy()#MLFrame(df_test[cols])

# %%
df_new.head()
# Out:
#        price  bedrooms  bathrooms  ...  view_2_0  view_3_0  view_4_0
# 0 221900.000         3      1.000  ...         0         0         0
# 1 538000.000         3      2.250  ...         0         0         0
# 2 180000.000         2      1.000  ...         0         0         0
# 3 604000.000         4      3.000  ...         0         0         0
# 4 510000.000         3      2.000  ...         0         0         0
#
# [5 rows x 20 columns]

# %%
df_new.get_vif_cols('price')
# Out:
# VIF columns > 6:
# sqft_basement    36.190
# sqft_above      117.930
# sqft_living     146.570
# dtype: float64
# sqft_basement    36.190
# sqft_above      117.930
# sqft_living     146.570
# dtype: float64

# %%
drop_cols = ['sqft_basement']
df_new.drop(drop_cols, axis=1).get_vif_cols('price')
# Out:
# VIF columns > 6:
# sqft_above    14.757
# sqft_living   15.581
# dtype: float64
# sqft_above    14.757
# sqft_living   15.581
# dtype: float64

# %%
drop_cols.append('sqft_above')
df_new.drop(drop_cols, axis=1).get_vif_cols('price')
# Out:
# VIF columns > 6:
# Series([], dtype: float64)
# Series([], dtype: float64)

# %%
df_new.drop(drop_cols, axis=1, inplace=True)
# Out:
# Empty MLFrame
# Columns: []
# Index: []

# %%
df_new = df_new[~df_new.find_outliers_Z('price')]
# Out:
# Found 406 outliers using z_score in price or ~ 1.88%

# %%
df_new.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'waterfront', 'condition', 'grade', 'yr_built', 'yr_renovated',
#        'sqft_living15', 'sqft_lot15', 'half_story', 'has_basement', 'view_1_0',
#        'view_2_0', 'view_3_0', 'view_4_0'],
#       dtype='object')

# %%
to_log = ['price', 'sqft_living', 'sqft_lot' ,
          'sqft_living15', 'sqft_lot15']
model = df_new.scale(to_log).model_and_plot('price')
# Out:
# Scaling:
#    price
#    sqft_living
#    sqft_lot
#    sqft_living15
#    sqft_lot15
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.629
# Model:                            OLS   Adj. R-squared:                  0.628
# Method:                 Least Squares   F-statistic:                     2109.
# Date:                Thu, 03 Sep 2020   Prob (F-statistic):               0.00
# Time:                        03:08:43   Log-Likelihood:                -19570.
# No. Observations:               21191   AIC:                         3.918e+04
# Df Residuals:                   21173   BIC:                         3.932e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ### Variance Inflation Factor

# %%
help(df.get_vif_cols)
# Out:
# Help on method get_vif_cols in module mltools.mlframe:
#
# get_vif_cols(target, threshold=6, verbose=True, inplace=False) method of mltools.mlframe.MLFrame instance
#     Computes Variance Inflation Factor
#     for the dataframe, and gets the columns
#     that are above the defined threshold
#
#     Parameters
#     ----------------------------------------
#     target[str]::
#         The column name to base the VIF on
#     threshold=6[int]::
#         The threshold that columns would be above
#         where they are an issue, and need to be
#         looked at
#     verbose[bool]::
#         Whether to print out the series or not
#     inplace[bool]::
#         Whether to return the series or not
#
#     Returns
#     ----------------------------------------
#     Depending on inplace
#     Series of variance_inflation_factor for each column
#
#     Example Usage
#     ----------------------------------------
#     >>> df = MLFrame(pd.read_csv('mltools/tests/auto-mpg.csv'))
# ...

# %%
if slow:
    df_ohe.get_vif_cols('price', verbose=True)
# Out:
# VIF columns > 6:
# sqft_basement    36.463
# sqft_above      120.790
# sqft_living     148.278
# dtype: float64

# %%
drop_cols = ['sqft_basement']
if slow:
    df_ohe.drop(drop_cols, axis=1).get_vif_cols('price', verbose=True)
# Out:
# VIF columns > 6:
# sqft_living   16.640
# sqft_above    16.793
# dtype: float64

# %%
drop_cols.append('sqft_above')
if slow:
    df_ohe.drop(drop_cols, axis=1).get_vif_cols('price', verbose=True)
# Out:
# VIF columns > 6:
# Series([], dtype: float64)

# %%
df_ohe.drop(drop_cols, axis=1, inplace=True)
# Out:
# Empty MLFrame
# Columns: []
# Index: []

# %%
help(df_ohe.clean_col_names)
# Out:
# Help on method clean_col_names in module mltools.mlframe:
#
# clean_col_names(inplace=False, verbose=True) method of mltools.mlframe.MLFrame instance
#     Cleans the column names of a DataFrame
#     for use in an R~Formula
#
#     Parameters
#     ----------------------------------------
#     inplace[bool]::
#         Defines whether to return a new dataframe or
#         mutate the dataframe
#     verbose[bool]::
#         Whether to show the difference between
#         the old columns and clean columns or not
#
#     Returns
#     ----------------------------------------
#     None if inplace, otherwise returns a copy of the dataframe
#
#     Example Usage
#     ----------------------------------------
#     >>> df = MLFrame(pd.read_csv('mltools/tests/auto-mpg.csv'))
#     >>> df.clean_col_names()
#     Columns changed:
#     model year --> model_year
#     car name --> car_name

# %%
df_ohe.clean_col_names(inplace=True)
# Out:
# Columns changed:

# %%
df_ohe.model_and_plot('price')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     1031.
# Date:                Thu, 03 Sep 2020   Prob (F-statistic):               0.00
# Time:                        03:09:03   Log-Likelihood:            -2.8955e+05
# No. Observations:               21597   AIC:                         5.793e+05
# Df Residuals:                   21508   BIC:                         5.800e+05
# Df Model:                          88
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Scrub 2

# %%
slow = False

# %%
df.head()
# Out:
#            id        date      price  ...  sqft_lot15  half_story  has_basement
# 0  7129300520  10/13/2014 221900.000  ...        5650           0             0
# 1  6414100192   12/9/2014 538000.000  ...        7639           0             1
# 2  5631500400   2/25/2015 180000.000  ...        8062           0             0
# 3  2487200875   12/9/2014 604000.000  ...        5000           0             1
# 4  1954400510   2/18/2015 510000.000  ...        7503           0             0
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# Model is <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000002BE5B8C3550>
#
# <class 'mltools.mlframe.MLFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  category
#  8   waterfront     21597 non-null  float64
#  9   view           21597 non-null  category
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  float64
#  14  yr_built       21597 non-null  int64
# ...

# %% [markdown]
# ### Define new categorical columns
# > drop cols
# - row 1 ( Has no effect on price
# - row 2/3 ( found high VIF after outlier removal and VIF analysis )

# %%
drop_cols = ['date', 'id', 'lat', 'long']
high_vif = ['grade', 'yr_built', 'bathrooms', 'sqft_living',
            'condition', 'bedrooms']
high_pval = ['yr_renovated', 'sqft_lot15']
high_pval_after_outlier_removal = ['month', 'zipcode']
drop_cols = drop_cols + high_vif + high_pval_after_outlier_removal

cat_cols = ['floors', 'view']
drop_cols
# Out:
# ['date',
#  'id',
#  'lat',
#  'long',
#  'grade',
#  'yr_built',
#  'bathrooms',
#  'sqft_living',
#  'condition',
#  'bedrooms',
#  'month',
#  'zipcode']

# %% [markdown]
# ### Make new dataframe

# %%
df2 = df.copy()

# %% [markdown]
# ### Making month column

# %%
df2['month'] = (df2['date'].apply(lambda x: x.split('/')[0]))

# %% [markdown]
# ### Fixing floors and bathrooms
# > Removing half floors and bathrooms

# %%
df2['floors'] = df2['floors'].astype('int32')
df2['bathrooms'] = df2['bathrooms'].astype('int32')
df2['floors'].value_counts(), df2['bathrooms'].value_counts()
# Out:
# (1    12583
#  2     8396
#  3      618
#  Name: floors, dtype: int64, 2    10539
#  1     8353
#  3     2228
#  4      338
#  0       75
#  5       48
#  6       12
#  8        2
#  7        2
#  Name: bathrooms, dtype: int64)

# %% [markdown]
# ### Outlier Removal

# %%
help(df2.outlier_removal)
# Out:
# Help on method outlier_removal in module mltools.mlframe:
#
# outlier_removal(columns=[], IQR=False, z_score=False, verbose=True) method of mltools.mlframe.MLFrame instance
#     Removes outliers based on IQR or z_score
#
#     Parameters
#     ----------------------------------------
#     column[list, str]::
#         The columns of which to remove outliers
#         if blank, removes from all columns
#     IQR[bool]::
#         Whether or not to remove outliers
#         using IQR method
#     z_score[bool]::
#         Whether or not to remove outliers
#         using z_score method
#     verbose[bool]::
#         Whether to print how many outliers were
#         found in each column or now
#
#     Returns
#     ----------------------------------------
#     Copy of dataframe with outliers removed
#
#     Example Usage
#     ----------------------------------------
#     >>> df = MLFrame(pd.read_csv('mltools/tests/auto-mpg.csv'))
#     >>> df = df.outlier_removal('horsepower',
# ...

# %% [markdown]
# #### Value counts before

# %%
outlier_removals = ['price']
outlier_removals = outlier_removals + high_pval
outlier_removals
# Out:
# ['price', 'yr_renovated', 'sqft_lot15']

# %%
for col in outlier_removals:
    print("Min:", df2[col].min(), "Max:", df2[col].max())
    print(df2[col].value_counts(), end='\n\n')
# Out:
# Min: 78000.0 Max: 7700000.0
# 350000.000    172
# 450000.000    172
# 550000.000    159
# 500000.000    152
# 425000.000    150
#              ...
# 870515.000      1
# 336950.000      1
# 386100.000      1
# 176250.000      1
# 884744.000      1
# Name: price, Length: 3622, dtype: int64
#
# Min: 0.0 Max: 2015.0
# 0.000       20853
# 2014.000       73
# 2003.000       31
# 2013.000       31
# 2007.000       30
#             ...
# 1946.000        1
# 1959.000        1
# 1971.000        1
# 1951.000        1
# 1954.000        1
# Name: yr_renovated, Length: 70, dtype: int64
#
# Min: 651 Max: 871200
# 5000      427
# 4000      356
# 6000      288
# 7200      210
# 4800      145
#          ...
# 11036       1
# 8989        1
# 871200      1
# 809         1
# 6147        1
# Name: sqft_lot15, Length: 8682, dtype: int64

# %% [markdown]
# #### Removal

# %%
num = len(df2)
for col in outlier_removals:
    df2[col] = df2[col].astype(float)
df2 = df2.outlier_removal(outlier_removals, z_score=True)
print('removed', num-len(df2))
# Out:
# Found 406 outliers using z_score in price or ~ 1.88%
# Removed
# Found 744 outliers using z_score in yr_renovated or ~ 3.44%
# Removed
# Found 363 outliers using z_score in sqft_lot15 or ~ 1.68%
# Removed
# removed 1441

# %% [markdown]
# #### Value counts after

# %%
for col in outlier_removals:
    print("Min:", df2[col].min(), "Max:", df2[col].max())
    print(df2[col].value_counts(), end='\n\n')
# Out:
# Min: 78000.0 Max: 1640000.0
# 350000.000    165
# 450000.000    162
# 500000.000    145
# 425000.000    144
# 550000.000    144
#              ...
# 386100.000      1
# 176250.000      1
# 575575.000      1
# 837700.000      1
# 884744.000      1
# Name: price, Length: 3419, dtype: int64
#
# Min: 0.0 Max: 0.0
# 0.000    20156
# Name: yr_renovated, dtype: int64
#
# Min: 651.0 Max: 94403.0
# 5000.000     398
# 4000.000     329
# 6000.000     272
# 7200.000     194
# 7500.000     137
#             ...
# 33955.000      1
# 13590.000      1
# 4233.000       1
# 3994.000       1
# 10873.000      1
# Name: sqft_lot15, Length: 8082, dtype: int64

# %%
len(df2)
# Out:
# 20156

# %%
#df2['zipcode'] = df2['zipcode'].astype('category')
drop_cols2 = ['date', 'month', 'zipcode', 'yr_renovated', 'sqft_basement']
model = df2.drop(drop_cols2, axis=1).model_and_plot('price')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.711
# Model:                            OLS   Adj. R-squared:                  0.711
# Method:                 Least Squares   F-statistic:                     2356.
# Date:                Thu, 03 Sep 2020   Prob (F-statistic):               0.00
# Time:                        03:09:04   Log-Likelihood:            -2.6702e+05
# No. Observations:               20156   AIC:                         5.341e+05
# Df Residuals:                   20134   BIC:                         5.342e+05
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
df2.model = model

# %% [markdown]
# ## Test Modeling

# %%
df2_ohe2 = df2.drop(drop_cols2, axis=1).one_hot_encode(['view', 'floors'])
df2_ohe2.get_vif_cols('price', verbose=True)
d = df2_ohe2.drop(['sqft_above'], axis=1).clean_col_names()
# Out:
# Added categorical columns
# 2 -> sqft_living
# 2 -> sqft_lot
# 2 -> floors
# 4 -> view
#
# VIF columns > 6:
# sqft_living   14.966
# sqft_above    15.834
# dtype: float64
#
# Columns changed:
# view_1.0 --> view_1_0
# view_2.0 --> view_2_0
# view_3.0 --> view_3_0
# view_4.0 --> view_4_0

# %% [markdown]
# ### Train Test Split df2_ohe2

# %%
if slow:
    model = d.train_test_split('price')

# %%
df2.drop(drop_cols, axis=1, inplace=True)
# Out:
# Empty MLFrame
# Columns: []
# Index: []

# %%
df2.info()
# Out:
# Model is <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000002BE5EB09DD8>
#
# <class 'mltools.mlframe.MLFrame'>
# Int64Index: 20156 entries, 0 to 21596
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          20156 non-null  float64
#  1   sqft_lot       20156 non-null  int64
#  2   floors         20156 non-null  int32
#  3   waterfront     20156 non-null  float64
#  4   view           20156 non-null  category
#  5   sqft_above     20156 non-null  int64
#  6   sqft_basement  20156 non-null  float64
#  7   yr_renovated   20156 non-null  float64
#  8   sqft_living15  20156 non-null  int64
#  9   sqft_lot15     20156 non-null  float64
#  10  half_story     20156 non-null  int64
#  11  has_basement   20156 non-null  int64
# dtypes: category(1), float64(5), int32(1), int64(5)
# memory usage: 1.8 MB

# %% [markdown]
# ### One hot encoding df2

# %%
for col in cat_cols:
    df2[col] = df2[col].astype('category')

# %%
df2_ohe = df2.one_hot_encode(cat_cols)
df2_ohe.clean_col_names(inplace=True)
df2_ohe.head()
# Out:
# Added categorical columns
# 2 -> sqft_lot
# 2 -> floors
# 4 -> view
#
# Columns changed:
# view_1.0 --> view_1_0
# view_2.0 --> view_2_0
# view_3.0 --> view_3_0
# view_4.0 --> view_4_0
#        price  sqft_lot  waterfront  ...  view_2_0  view_3_0  view_4_0
# 0 221900.000      5650       0.000  ...         0         0         0
# 2 180000.000     10000       0.000  ...         0         0         0
# 3 604000.000      5000       0.000  ...         0         0         0
# 4 510000.000      8080       0.000  ...         0         0         0
# 6 257500.000      6819       0.000  ...         0         0         0
#
# [5 rows x 16 columns]

# %%
df2_ohe.dtypes.value_counts()
# Out:
# uint8      6
# float64    5
# int64      5
# dtype: int64

# %% [markdown]
# ### Check vif correlation

# %%
if slow:
    df2_ohe.get_vif_cols('price', verbose=True)

# %%
df2_ohe.model_and_plot('price')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.513
# Method:                 Least Squares   F-statistic:                     1520.
# Date:                Thu, 03 Sep 2020   Prob (F-statistic):               0.00
# Time:                        03:09:04   Log-Likelihood:            -2.7225e+05
# No. Observations:               20156   AIC:                         5.445e+05
# Df Residuals:                   20141   BIC:                         5.447e+05
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
pvals = df2_ohe.model.pvalues
high_p = pvals[pvals > .05]
high_p.sort_values()
# Out:
# floors_2   0.710
# dtype: float64

# %% [markdown]
# ## Explore

# %% [markdown]
# ### Outlier Removal

# %%
num = len(df_ohe)
df_ohe = df_ohe[~df_ohe.find_outliers_IQR('price')]
print('Removed', num-len(df_ohe))
df_ohe.head()
# Out:
# Found 1158 outliers using IQR in price or ~ 5.36%
# Removed 1158

# %%
### Finding best outliers to remove based on r_squared

# %%
if False:  # est: 30 minute runtime
    for i in range(100):
        save = {}
        for col in removals:
            df_ohe = df_ohe[~df_ohe.find_outliers_IQR(col)]
        for col in df_ohe:
            new = df_ohe[~df_ohe.find_outliers_IQR(col)]
            new.lrmodel('price', inplace=True)
            save[col] = new.model.rsquared
        removals.append(sorted(save.items(), key=lambda x: x[1])[-1][0])
removals = ['sqft_lot15', 'bedrooms',
            'sqft_basement', 'yr_built', 'sqft_lot']

# %%
# main = len(df_ohe)
# for col in removals:
#     df_ohe = df_ohe[~df_ohe.find_outliers_IQR(col)]
#     print("removed", main-len(df_ohe), "with", col)
#     main = len(df_ohe)

# %%
len(df_ohe)
# Out:
# 20439

# %%
df_ohe.model_and_plot('price')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.832
# Model:                            OLS   Adj. R-squared:                  0.831
# Method:                 Least Squares   F-statistic:                     1142.
# Date:                Thu, 03 Sep 2020   Prob (F-statistic):               0.00
# Time:                        03:07:28   Log-Likelihood:            -2.6106e+05
# No. Observations:               20439   AIC:                         5.223e+05
# Df Residuals:                   20350   BIC:                         5.230e+05
# Df Model:                          88
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
# None
if slow:
    df_ohe.get_vif_cols('price')

# %%
high_p = df_ohe.model.pvalues[df_ohe.model.pvalues > .05]
high_p
# Out:
# sqft_lot15      0.910
# zipcode_98002   0.191
# zipcode_98003   0.414
# zipcode_98022   0.935
# zipcode_98030   0.434
# zipcode_98031   0.140
# zipcode_98032   0.458
# zipcode_98042   0.137
# floors_2        0.278
# dtype: float64

# %%
num = len(df_ohe)
for col in high_p.index:
    df_ohe = df_ohe[~df_ohe.find_outliers_IQR(col)]
    print("removed", num-len(df_ohe), "with", col)
    num = len(df_ohe)
# Out:
# Found 1937 outliers using IQR in sqft_lot15 or ~ 9.48%
# removed 1937 with sqft_lot15
# Found 197 outliers using IQR in zipcode_98002 or ~ 1.06%
# removed 197 with zipcode_98002
# Found 269 outliers using IQR in zipcode_98003 or ~ 1.47%
# removed 269 with zipcode_98003
# Found 151 outliers using IQR in zipcode_98022 or ~ 0.84%
# removed 151 with zipcode_98022
# Found 251 outliers using IQR in zipcode_98030 or ~ 1.4%
# removed 251 with zipcode_98030
# Found 266 outliers using IQR in zipcode_98031 or ~ 1.51%
# removed 266 with zipcode_98031
# Found 118 outliers using IQR in zipcode_98032 or ~ 0.68%
# removed 118 with zipcode_98032
# Found 462 outliers using IQR in zipcode_98042 or ~ 2.68%
# removed 462 with zipcode_98042
# Found 0 outliers using IQR in floors_2 or ~ 0.0%
# removed 0 with floors_2

# %% [markdown]
# ## Goal Model

# %%
df_ohe.model_and_plot('price')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.827
# Model:                            OLS   Adj. R-squared:                  0.826
# Method:                 Least Squares   F-statistic:                     985.3
# Date:                Thu, 03 Sep 2020   Prob (F-statistic):               0.00
# Time:                        03:07:29   Log-Likelihood:            -2.1436e+05
# No. Observations:               16788   AIC:                         4.289e+05
# Df Residuals:                   16706   BIC:                         4.295e+05
# Df Model:                          81
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
high_p = df_ohe.model.pvalues[df_ohe.model.pvalues > .05]
high_p
# Out:
# floors_2   0.224
# dtype: float64

# %%
for col in df_ohe.columns:
    if 'floors' in col:
        df_ohe.drop(col, axis=1, inplace=True)

# %%
model = df_ohe.model_and_plot('price')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.825
# Method:                 Least Squares   F-statistic:                     1005.
# Date:                Thu, 03 Sep 2020   Prob (F-statistic):               0.00
# Time:                        03:07:30   Log-Likelihood:            -2.1440e+05
# No. Observations:               16788   AIC:                         4.290e+05
# Df Residuals:                   16708   BIC:                         4.296e+05
# Df Model:                          79
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
high_p = model.pvalues[model.pvalues > .05]
high_p
# Out:
# zipcode_98002   0.360
# zipcode_98003   0.410
# zipcode_98022   0.174
# dtype: float64

# %%
df_ohe.model = model

# %%
df_ohe.plot_coef()
# Out:
# <style  type="text/css" >
# #T_83a31c64_edbc_11ea_b7a4_04d9f5827febrow0_col0{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_83a31c64_edbc_11ea_b7a4_04d9f5827febrow1_col0{
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }#T_83a31c64_edbc_11ea_b7a4_04d9f5827febrow2_col0{
#             background-color:  #16803c;
#             color:  #f1f1f1;
#         }#T_83a31c64_edbc_11ea_b7a4_04d9f5827febrow3_col0,#T_83a31c64_edbc_11ea_b7a4_04d9f5827febrow4_col0{
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }#T_83a31c64_edbc_11ea_b7a4_04d9f5827febrow5_col0{
#             background-color:  #1a843f;
#             color:  #000000;
#         }#T_83a31c64_edbc_11ea_b7a4_04d9f5827febrow6_col0{
#             background-color:  #1d8640;
#             color:  #000000;
#         }#T_83a31c64_edbc_11ea_b7a4_04d9f5827febrow7_col0{
#             background-color:  #228a44;
# ...

# %%
df_ohe.drop([x for x in df_ohe.columns if 'zipcode' in x], axis=1).plot_corr(annot=True)
# Out:
# (<Figure size 1800x1800 with 2 Axes>, <AxesSubplot:>)

# %%
high_corr_drop = ['bathrooms', 'bedrooms', 'sqft_living', 'sqft_living15', 'yr_built', 'waterfront', 'sqft_lot15']
df_ohe.drop(high_corr_drop, axis=1).drop([x for x in df_ohe.columns if 'zipcode' in x], axis=1).plot_corr(annot=True)
# Out:
# (<Figure size 1800x1800 with 2 Axes>, <AxesSubplot:>)

# %%
# df_ohe = MLFrame(df_ohe[~df_ohe.find_outliers_IQR('bedrooms')])

# %%
df_ohe.drop(high_corr_drop, axis=1).model_and_plot('price')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.735
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     643.5
# Date:                Thu, 03 Sep 2020   Prob (F-statistic):               0.00
# Time:                        03:07:32   Log-Likelihood:            -2.1794e+05
# No. Observations:               16788   AIC:                         4.360e+05
# Df Residuals:                   16715   BIC:                         4.366e+05
# Df Model:                          72
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
if slow:  # shows none
    df_ohe.get_vif_cols('price', verbose=True)
df_ohe.plot_corr()
# Out:
# (<Figure size 1800x1800 with 2 Axes>, <AxesSubplot:>)

# %%
high_p = model.pvalues[model.pvalues > .05]
high_p
# Out:
# zipcode_98002   0.360
# zipcode_98003   0.410
# zipcode_98022   0.174
# dtype: float64

# %%
num = len(df_ohe)
for col in df_ohe.columns:
    if 'zipcode' in col:
        df_ohe.drop(col, axis=1, inplace=True)

# %% [markdown]
# ## Model

# %%
df_ohe.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'waterfront', 'condition', 'grade', 'yr_built', 'yr_renovated',
#        'sqft_living15', 'sqft_lot15', 'half_story', 'has_basement', 'view_1_0',
#        'view_2_0', 'view_3_0', 'view_4_0'],
#       dtype='object')

# %%
drop_cols = ['sqft_lot']  # drop high_p value('sqft_lot')
df_ohe.drop(drop_cols, axis=1, inplace=True)
model = df_ohe.model_and_plot('price')
high_p = model.pvalues[model.pvalues > .05]
print(high_p)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.596
# Model:                            OLS   Adj. R-squared:                  0.596
# Method:                 Least Squares   F-statistic:                     1549.
# Date:                Thu, 03 Sep 2020   Prob (F-statistic):               0.00
# Time:                        03:07:34   Log-Likelihood:            -2.2147e+05
# No. Observations:               16788   AIC:                         4.430e+05
# Df Residuals:                   16771   BIC:                         4.431e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
df_ohe.model = model
df_ohe.plot_coef()
# Out:
# <style  type="text/css" >
# #T_86063e70_edbc_11ea_8f88_04d9f5827febrow0_col0{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_86063e70_edbc_11ea_8f88_04d9f5827febrow1_col0{
#             background-color:  #004c1e;
#             color:  #f1f1f1;
#         }#T_86063e70_edbc_11ea_8f88_04d9f5827febrow2_col0{
#             background-color:  #005b25;
#             color:  #f1f1f1;
#         }#T_86063e70_edbc_11ea_8f88_04d9f5827febrow3_col0{
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }#T_86063e70_edbc_11ea_8f88_04d9f5827febrow4_col0{
#             background-color:  #026f2e;
#             color:  #f1f1f1;
#         }#T_86063e70_edbc_11ea_8f88_04d9f5827febrow5_col0{
#             background-color:  #077331;
#             color:  #f1f1f1;
#         }#T_86063e70_edbc_11ea_8f88_04d9f5827febrow6_col0{
#             background-color:  #0c7735;
#             color:  #f1f1f1;
# ...

# %%
df_ohe.plot_corr()
# Out:
# (<Figure size 1800x1800 with 2 Axes>, <AxesSubplot:>)

# %%
# Dropping high p_value
df_ohe.drop(['sqft_lot'], axis=1).train_test_split('price')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-a3e4b41dbbe4> in <module>
#       1 # Dropping high p_value
# ----> 2 df_ohe.drop(['sqft_lot'], axis=1).train_test_split('price')
#
# ~\DS\Projects\mod-2-project\mltools\mlframe.py in inner(self, *args, **kwargs)
#     335         @inherit_docstrings
#     336         def inner(self, *args, **kwargs):
# --> 337             frame = func(self, *args, **kwargs)
#     338             frame = MLFrame(frame)
#     339             frame.model = self.model
#
# ~\DS\Projects\mod-2-project\mltools\mlframe.py in drop(self, *args, **kwargs)
#     343     @wrapper
#     344     def drop(self, *args, **kwargs):
# --> 345         return super(MLFrame, self).drop(*args, **kwargs)
#     346
#     347     @wrapper
#
# ...

# %% [markdown]
# >**Interpretation**
# - **grade** and **condition** are some of the strongest coefficients
# - adding a **bathroom** adds an average of 23,000\\$ to house value
# - adding a **basement** adds 11,000\\$ to house value
# - adding a **half story** adds 11,000\\$ to house value
# - each **square foot** of living added adds 74\\$ to house value
# - adding a **bedroom** removes 10,000\\$ from house value
